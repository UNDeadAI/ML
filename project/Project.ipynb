# %%
from __future__ import print_function
import collections
import os
import tensorflow as tf
from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Embedding, Flatten, Dropout, TimeDistributed, Reshape, Lambda
from keras.layers import LSTM
from keras.optimizers import RMSprop, Adam, SGD
from keras import backend as K
from keras.utils import to_categorical
from keras.callbacks import ModelCheckpoint
import numpy as np
import pdb
# Out:
# /usr/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train_path = "dataset/cured_text/1M/wiki_00"
valid_path = "dataset/no_punctuation/1M/wiki_00"
test_path = "dataset/cured_text/1M/wiki_01"

# %%
def read_words(filename):
    with tf.gfile.GFile(filename, "r") as f:
        return f.read().replace("\n", "<eof>").split()

# %%
def build_vocab(filename):
    data = read_words(filename)

    counter = collections.Counter(data)        
    count_pairs = sorted(counter.items(), key=lambda x: (-x[1], x[0]))        

    words, _ = list(zip(*count_pairs)) 
    print(count_pairs)
    word_to_id = dict(zip(words, range(len(words))))
    
    return word_to_id

# %%
a = build_vocab(valid_path)
# Out:
# [('de', 11031), ('la', 5721), ('y', 4584), ('en', 4325), ('el', 4097), ('que', 2939), ('<num>', 2479), ('los', 2397), ('a', 2338), ('del', 2203), ('se', 2007), ('las', 1901), ('un', 1564), ('por', 1555), ('con', 1399), ('una', 1348), ('es', 1221), ('como', 1145), ('o', 975), ('ms', 830), ('para', 766), ('su', 744), ('La', 709), ('son', 705), ('En', 696), ('al', 662), ('El', 645), ('no', 573), ('entre', 417), ('lo', 382), ('Los', 362), ('Las', 341), ('fue', 307), ('sus', 300), ('<num><num>', 297), ('especies', 279), ('tambin', 268), ('ha', 258), ('parte', 246), ('ser', 243), ('Amrica', 239), ('este', 235), ('puede', 235), ('aos', 233), ('hasta', 228), ('pases', 225), ('desde', 208), ('sobre', 208), ('dos', 207), ('pueden', 205), ('pero', 201), ('han', 200), ('otros', 189), ('esta', 183), ('muy', 183), ('forma', 177), ('donde', 175), ('est', 175), ('pas', 174), ('mayor', 172), ('gran', 171), ('sin', 167), ('<eof>', 164), ('tiene', 159), ('plantas', 156), ('arqueas', 154), ('A', 152), ('cada', 151), ('estos', 148), ('aunque', 145), ('poblacin', 145), ('gnero', 143), ('familia', 142), ('Por', 140), ('ao', 140), ('Se', 138), ('ejemplo', 134), ('tipo', 133), ('e', 128), ('siglo', 128), ('ya', 128), ('<num>%', 126), ('alimentos', 126), ('nombre', 124), ('<num><eof>', 123), ('veces', 123), ('tienen', 122), ('algunos', 120), ('agujero', 119), ('estn', 119), ('Andorra', 118), ('Estados', 118), ('sistema', 117), ('tres', 116), ('cuando', 115), ('si', 115), ('mundo', 114), ('uno', 113), ('nmero', 110), ('otras', 110), ('Einstein', 107), ('embargo', 107), ('sido', 107), ('as', 106), ('grandes', 106), ('Es', 105), ('Argentina', 104), ('flores', 102), ('solo', 101), ('tanto', 101), ('todo', 101), ('Unidos', 100), ('estas', 100), ('vez', 100), ('hay', 98), ('mayora', 98), ('Brasil', 97), ('cual', 97), ('le', 97), ('muchas', 97), ('gneros', 96), ('luz', 96), ('regin', 93), ('tiempo', 93), ('era', 92), ('millones', 92), ('Sur', 91), ('grupo', 91), ('Sin', 89), ('hacia', 89), ('menos', 89), ('Asia', 88), ('bien', 88), ('dentro', 88), ('desarrollo', 88), ('durante', 88), ('fueron', 88), ('algunas', 87), ('especie', 86), ('mientras', 86), ('da', 85), ('partir', 85), ('teora', 85), ('primer', 84), ('Chile', 83), ('Tambin', 83), ('hojas', 83), ('importante', 83), ('diferentes', 82), ('general', 82), ('travs', 82), ('siendo', 81), ('energa', 80), ('alcaloides', 79), ('muchos', 79), ('segn', 79), ('todos', 79), ('<num><num>%', 78), ('varios', 78), ('animales', 77), ('importantes', 76), ('mismo', 76), ('lugar', 75), ('Este', 74), ('Europa', 74), ('Un', 73), ('agujeros', 73), ('largo', 73), ('nivel', 73), ('origen', 72), ('otro', 72), ('sur', 72), ('vida', 72), ('debido', 71), ('hace', 71), ('primera', 71), ('continente', 70), ('despus', 70), ('negro', 70), ('norte', 70), ('adems', 69), ('antes', 69), ('Adems', 68), ('Espaa', 68), ('base', 68), ('caso', 68), ('forman', 68), ('uso', 68), ('agua', 67), ('usualmente', 67), ('%', 66), ('cuales', 66), ('mundial', 66), ('Esto', 65), ('casi', 65), ('arqueologa', 64), ('grupos', 64), ('presencia', 64), ('restos', 64), ('Esta', 63), ('Su', 63), ('ajedrez', 63), ('tales', 63), ('Norte', 62), ('Colombia', 61), ('De', 61), ('Mxico', 61), ('agricultura', 61), ('caracteres', 61), ('haba', 61), ('cuatro', 60), ('cuenta', 60), ('encuentran', 60), ('gusano', 60), ('misma', 60), ('Vivaldi', 59), ('ellos', 59), ('Afganistn', 58), ('crecimiento', 58), ('generalmente', 58), ('estudio', 57), ('organismos', 57), ('unos', 57), ('zonas', 57), ('Per', 56), ('Son', 56), ('Venezuela', 56), ('bajo', 56), ('entonces', 56), ('estado', 56), ('historia', 56), ('piezas', 56), ('alergia', 55), ('existen', 55), ('todas', 55), ('San', 54), ('principalmente', 54), ('debe', 53), ('especialmente', 53), ('ASCII', 52), ('Para', 52), ('contra', 52), ('otra', 52), ('tener', 52), ('Canad', 51), ('masa', 51), ('varias', 51), ('cantidad', 50), ('ese', 50), ('et', 50), ('medio', 50), ('poco', 50), ('posible', 50), ('semillas', 50), ('territorio', 50) ...

# %%
def file_to_word_ids(filename, word_to_id):
    data = read_words(filename)
    return [word_to_id[word] for word in data if word in word_to_id]

# %%
def load_data():        
    # build the complete vocabulary, then convert text data to list of integers
    word_to_id = build_vocab(train_path)
    train_data = file_to_word_ids(train_path, word_to_id)
    valid_data = file_to_word_ids(valid_path, word_to_id)
    test_data = file_to_word_ids(test_path, word_to_id)
    vocabulary = len(word_to_id)
    reversed_dictionary = dict(zip(word_to_id.values(), word_to_id.keys()))

    #print(train_data[:5])
    #print(word_to_id)
    #print(vocabulary)
    #print(" ".join([reversed_dictionary[x] for x in train_data[:10]]))
    return train_data, valid_data, test_data, vocabulary, reversed_dictionary

train_data, valid_data, test_data, vocabulary, reversed_dictionary = load_data()

# %%
valid_data
# Out:
# [116,
#  116,
#  2831,
#  763,
#  0,
#  116,
#  15,
#  11,
#  737,
#  86,
#  4585,
#  8,
#  2912,
#  0,
#  224,
#  15002,
#  3,
#  299,
#  1401,
#  0,
#  1049,
#  21964,
#  2,
#  750,
#  677,
#  52,
#  0,
#  303,
#  15,
#  4,
#  5427,
#  27783,
#  166,
#  316,
#  54,
#  6104,
#  3,
#  529,
#  4448,
#  13,
#  14,
#  73,
#  458,
#  0,
#  6879,
#  13490,
#  500,
#  6837,
#  166,
#  630,
#  15,
#  116,
#  1,
#  2564,
#  1025,
#  4788,
#  5914,
#  0,
#  1056,
#  3615,
#  2,
#  54,
#  2081,
#  3,
#  6,
#  7418,
#  27,
#  254,
#  2,
#  438,
#  13,
#  14,
#  1350,
#  733,
#  0,
#  2974,
#  2027,
#  3053,
#  12,
#  4,
#  216,
#  13,
#  254,
#  13,
#  10,
#  20916,
#  20489,
#  0,
#  3733,
#  1343,
#  2,
#  16850,
#  2,
#  12,
#  4,
#  207,
#  13,
#  438,
#  13,
#  6,
#  8554,
#  0,
#  14299,
#  2,
#  7418,
#  16793,
#  166,
#  79,
#  3522,
#  15,
#  14,
#  21956,
#  27782,
#  5,
#  58,
#  16,
#  3408,
#  0,
#  299,
#  7,
#  6,
#  8418,
#  0,
#  116,
#  4,
#  1287,
#  0,
#  1343,
#  2,
#  4,
#  859,
#  0,
#  438,
#  2,
#  16,
#  2004,
#  0,
#  1219,
#  25,
#  859,
#  8,
#  1219,
#  24,
#  1274,
#  790,
#  15,
#  4,
#  1698,
#  5,
#  21408,
#  13,
#  4,
#  449,
#  2,
#  3,
#  269,
#  576,
#  13,
#  4,
#  642,
#  2,
#  4,
#  2857,
#  242,
#  58,
#  2269,
#  48,
#  410,
#  11,
#  496,
#  0,
#  10069,
#  1720,
#  3,
#  21,
#  168,
#  0,
#  22832,
#  17,
#  22068,
#  1066,
#  16,
#  12,
#  159,
#  10,
#  9429,
#  5,
#  27436,
#  3,
#  6810,
#  1,
#  8446,
#  22306,
#  5,
#  9,
#  21414,
#  25,
#  641,
#  12,
#  6,
#  2214,
#  0,
#  68,
#  13,
#  613,
#  1111,
#  66,
#  15,
#  14,
#  997,
#  607,
#  0,
#  397,
#  2,
#  1,
#  10069,
#  8,
#  86,
#  24363,
#  195,
#  10,
#  22832,
#  21,
#  168,
#  0,
#  5311,
#  5794,
#  9,
#  29172,
#  7,
#  715,
#  1154,
#  17,
#  1756,
#  133,
#  4,
#  803,
#  31046,
#  0,
#  3924,
#  2,
#  2662,
#  283,
#  315,
#  154,
#  6183,
#  2,
#  18787,
#  1132,
#  14,
#  6069,
#  28744,
#  45,
#  1,
#  2554,
#  515,
#  350,
#  7,
#  124,
#  8,
#  10735,
#  2,
#  215,
#  12,
#  20,
#  1522,
#  0,
#  2840,
#  9062,
#  1522,
#  5,
#  27973,
#  19,
#  254,
#  45,
#  4,
#  621,
#  0,
#  774,
#  0,
#  1641,
#  92,
#  4,
#  26633,
#  18,
#  356,
#  0,
#  224,
#  24,
#  162,
#  0,
#  1,
#  579,
#  116,
#  15,
#  22105,
#  66,
#  9,
#  47,
#  24082,
#  330,
#  655,
#  25,
#  346,
#  24,
#  2713,
#  0,
#  2202,
#  8,
#  763,
#  0,
#  116,
#  520,
#  1167,
#  15,
#  17801,
#  54,
#  641,
#  12,
#  183,
#  21673,
#  46,
#  12,
#  60,
#  8417,
#  22,
#  2608,
#  0,
#  116,
#  9,
#  3898,
#  2831,
#  3,
#  4747,
#  2,
#  15,
#  31038,
#  10802,
#  2606,
#  18982,
#  2,
#  6323,
#  1,
#  2293,
#  5168,
#  908,
#  18,
#  356,
#  5,
#  10,
#  90,
#  46,
#  21,
#  4,
#  341,
#  9,
#  912,
#  4,
#  2713,
#  0,
#  116,
#  19,
#  22329,
#  0,
#  10,
#  3969,
#  0,
#  16520,
#  2,
#  22,
#  3420,
#  8,
#  24765,
#  1459,
#  24,
#  439,
#  3,
#  3175,
#  24,
#  439,
#  4857,
#  1,
#  1153,
#  7260,
#  14520,
#  1560,
#  17912,
#  2,
#  1,
#  848,
#  31,
#  767,
#  12,
#  7136,
#  16386,
#  24,
#  24765,
#  9,
#  3898,
#  2831,
#  3,
#  13246,
#  2,
#  9,
#  4316,
#  12,
#  147,
#  125,
#  4,
#  534,
#  0,
#  1001,
#  0,
#  4751,
#  116,
#  31,
#  9163,
#  0,
#  243,
#  13,
#  11,
#  79,
#  5,
#  1830,
#  25,
#  400,
#  1,
#  2097,
#  4857,
#  4,
#  126,
#  3455,
#  8,
#  17299,
#  377,
#  17243,
#  15616,
#  5370,
#  1,
#  609,
#  7,
#  37,
#  193,
#  7,
#  565,
#  0,
#  715,
#  19,
#  20,
#  1412,
#  213,
#  199,
#  7647,
#  13,
#  10,
#  10241,
#  12,
#  4,
#  305,
#  3,
#  6740,
#  9,
#  977,
#  11,
#  1610,
#  0,
#  5427,
#  268,
#  4,
#  99,
#  4,
#  1707,
#  7162,
#  0,
#  3034,
#  2,
#  4,
#  1287,
#  0,
#  1343,
#  20969,
#  4,
#  303,
#  0,
#  214,
#  316,
#  17433,
#  184,
#  1,
#  1225,
#  2152,
#  13146,
#  16,
#  9216,
#  8,
#  316,
#  4548,
#  7,
#  32,
#  679,
#  9039,
#  41,
#  116,
#  2531,
#  2539,
#  14572,
#  2116,
#  7,
#  2183,
#  20,
#  2414,
#  3,
#  6759,
#  12,
#  28085,
#  5705,
#  0,
#  6,
#  1502,
#  283,
#  4,
#  920,
#  8,
#  791,
#  179,
#  0,
#  386,
#  9,
#  7932,
#  3,
#  24517,
#  3542,
#  25,
#  439,
#  1027,
#  16,
#  3,
#  1,
#  14454,
#  0,
#  1,
#  2,
#  56,
#  860,
#  8,
#  316,
#  16,
#  22,
#  1892,
#  2,
#  4986,
#  51,
#  4,
#  298,
#  0,
#  781,
#  0,
#  1863,
#  9,
#  2271,
#  11,
#  29774,
#  23778,
#  13,
#  26156,
#  0,
#  28168,
#  2,
#  5,
#  8387,
#  170,
#  386,
#  20145,
#  2,
#  10298,
#  0,
#  2636,
#  13,
#  101,
#  761,
#  7,
#  1,
#  5723,
#  0,
#  10,
#  554,
#  61,
#  179,
#  10,
#  21726,
#  2,
#  9,
#  2721,
#  8533,
#  10296,
#  0,
#  6,
#  361,
#  5,
#  4452,
#  12,
#  20,
#  316,
#  1,
#  425,
#  8,
#  20164,
#  25,
#  19988,
#  0,
#  6,
#  4373,
#  5,
#  180,
#  3,
#  22,
#  147,
#  798,
#  3307,
#  41,
#  6,
#  9,
#  232,
#  3,
#  1,
#  3259,
#  5,
#  501,
#  4,
#  5824,
#  278,
#  17024,
#  41,
#  4,
#  616,
#  0,
#  14239,
#  12,
#  6,
#  7418,
#  283,
#  4,
#  69,
#  7554,
#  4,
#  377,
#  2895,
#  30339,
#  7,
#  6,
#  5,
#  2830,
#  1,
#  15575,
#  2801,
#  2,
#  39,
#  0,
#  17727,
#  59,
#  184,
#  6,
#  3462,
#  21211,
#  214,
#  316,
#  30996,
#  1,
#  900,
#  13,
#  4,
#  1100,
#  24129,
#  21,
#  4,
#  77,
#  535,
#  16400,
#  6,
#  3256,
#  3,
#  1,
#  2209,
#  0,
#  24142,
#  20,
#  725,
#  109,
#  4,
#  300,
#  66,
#  4059,
#  19556,
#  3,
#  6,
#  7418,
#  1666,
#  4857,
#  4076,
#  1,
#  16381,
#  7211,
#  2,
#  20,
#  10576,
#  1021,
#  4,
#  16966,
#  25498,
#  3,
#  4,
#  77,
#  116,
#  3,
#  4,
#  377,
#  21,
#  1,
#  666,
#  2534,
#  6,
#  1464,
#  0,
#  116,
#  2843,
#  7,
#  28059,
#  25,
#  14985,
#  0,
#  1343,
#  25,
#  36,
#  20549,
#  12,
#  535,
#  4,
#  14724,
#  0,
#  1,
#  438,
#  3061,
#  301,
#  438,
#  7,
#  17543,
#  1658,
#  3,
#  4,
#  77,
#  226,
#  1,
#  725,
#  0,
#  37,
#  5375,
#  109,
#  4,
#  216,
#  51,
#  180,
#  933,
#  18,
#  4249,
#  10,
#  190,
#  4385,
#  5490,
#  0,
#  208,
#  906,
#  19,
#  4,
#  1707,
#  2,
#  3,
#  15347,
#  3865,
#  20547,
#  131,
#  6,
#  2210,
#  2,
#  679,
#  5118,
#  41,
#  6,
#  1464,
#  0,
#  116,
#  25,
#  1287,
#  0,
#  1343,
#  21,
#  4,
#  4,
#  27331,
#  7,
#  565,
#  0,
#  1435,
#  1419,
#  4002,
#  32,
#  679,
#  4480,
#  2336,
#  2,
#  25779,
#  7,
#  1,
#  68,
#  14698,
#  66,
#  8352,
#  1,
#  2414,
#  41,
#  116,
#  30953,
#  4,
#  892,
#  3615,
#  3,
#  11,
#  29979,
#  23108,
#  21,
#  14307,
#  0,
#  14698,
#  5414,
#  2329,
#  13,
#  14308,
#  1658,
#  0,
#  24,
#  2329,
#  0,
#  3072,
#  4846,
#  667,
#  0,
#  3034,
#  2,
#  15348,
#  0,
#  3,
#  4608,
#  4,
#  892,
#  9037,
#  0,
#  116,
#  12,
#  39,
#  0,
#  6,
#  5378,
#  0,
#  3034,
#  2063,
#  25716,
#  2604,
#  20,
#  305,
#  3,
#  1100,
#  0,
#  4975,
#  2,
#  749,
#  18,
#  1081,
#  4,
#  1100,
#  0,
#  438,
#  267,
#  675,
#  0,
#  6,
#  1941,
#  27,
#  3072,
#  4846,
#  626,
#  0,
#  3034,
#  2,
#  1099,
#  0,
#  4,
#  534,
#  0,
#  1001,
#  0,
#  6740,
#  9,
#  9059,
#  4,
#  126,
#  27776,
#  3,
#  5,
#  5728,
#  6,
#  3431,
#  8,
#  305,
#  0,
#  60,
#  583,
#  1,
#  5758,
#  8,
#  763,
#  0,
#  116,
#  2,
#  972,
#  10,
#  4417,
#  0,
#  6,
#  1502,
#  3,
#  389,
#  0,
#  22321,
#  2,
#  3950,
#  2336,
#  12,
#  28,
#  5,
#  9,
#  3353,
#  11,
#  21117,
#  9037,
#  66,
#  384,
#  26,
#  98,
#  10120,
#  7,
#  1,
#  4874,
#  0,
#  71,
#  5,
#  4,
#  5375,
#  0,
#  3034,
#  107,
#  31402,
#  10616,
#  2,
#  116,
#  569,
#  110,
#  0,
#  10,
#  4238,
#  0,
#  1,
#  1948,
#  7107,
#  59,
#  184,
#  16,
#  675,
#  0,
#  1,
#  1044,
#  0,
#  14,
#  4288,
#  24090,
#  3,
#  6331,
#  5057,
#  0,
#  7133,
#  12,
#  39,
#  8,
#  1707,
#  0,
#  3034,
#  45,
#  51,
#  1814,
#  31554,
#  10,
#  598,
#  ...]
